# %%
# !pip install pyreadstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 18.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/MyDrive')
# Out:
# Mounted at /content/MyDrive

# %%
df = pd.read_excel('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-67185250d7b3> in <cell line: 2>()
#       1 df = pd.read_excel('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA.xlsx')
# ----> 2 df.coumns.to_list()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'coumns'

# %%
df.describe()
# Out:
#        NINGUNOTRODIAG    ANSIEDAD   DEPRESIÓN      TPERSO    TBIPOLAR  \
# count      583.000000  583.000000  583.000000  583.000000  583.000000
# mean         0.600343    0.250429    0.204117    0.039451    0.003431
# std          0.490248    0.433632    0.403401    0.194833    0.058520
# min          0.000000    0.000000    0.000000    0.000000    0.000000
# 25%          0.000000    0.000000    0.000000    0.000000    0.000000
# 50%          1.000000    0.000000    0.000000    0.000000    0.000000
# 75%          1.000000    0.500000    0.000000    0.000000    0.000000
# max          1.000000    1.000000    1.000000    1.000000    1.000000
#
#        TPSICOTICO  OtrosdiagnósticosademásdelTCA_B
# count  583.000000                       583.000000
# mean     0.003431                         0.054889
# std      0.058520                         0.227958
# min      0.000000                         0.000000
# 25%      0.000000                         0.000000
# ...

# %%
df_G = df[['AÑOSPADECIENDO', 'AÑOSTTO', 'ADMINISTRACION', 'EDADCOMIENZO', 'ESTADO', 'SEXO', 'IMPRESION_PSQ1', 'IMPRESION_PSQ2']]

# %%
df = df.drop(['AÑOSPADECIENDO', 'AÑOSTTO', 'ADMINISTRACION', 'EDADCOMIENZO', 'ESTADO', 'SEXO', 'IMPRESION_PSQ1', 'IMPRESION_PSQ2'], axis=1)

# %%
df_T1 = df.loc[:, ~df.columns.str.endswith(('_T2', '_T3'))]
df_T2 = df.filter(regex='_T2$')
df_T3 = df.filter(regex='_T3$')

# %%
df_G.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AÑOSPADECIENDO  583 non-null    object
#  1   AÑOSTTO         583 non-null    object
#  2   ADMINISTRACION  583 non-null    object
#  3   EDADCOMIENZO    583 non-null    object
#  4   ESTADO          583 non-null    object
#  5   SEXO            583 non-null    object
#  6   IMPRESION_PSQ1  583 non-null    object
#  7   IMPRESION_PSQ2  583 non-null    object
# dtypes: object(8)
# memory usage: 36.6+ KB

# %%
df_T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Columns: 173 entries, FECHA to RESI_ULTIM25
# dtypes: int64(7), object(166)
# memory usage: 788.1+ KB

# %%
df_T2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Columns: 173 entries, FECHA_T2 to RESI_ULTIM25_T2
# dtypes: object(173)
# memory usage: 788.1+ KB

# %%
df_T3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Columns: 173 entries, FECHA_T3 to RESI_ULTIM25_T3
# dtypes: object(173)
# memory usage: 788.1+ KB

# %%
df_G.to_csv('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA_general.csv', index=True, index_label='ID')
df_T1.to_csv('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA_T1.csv', index=True, index_label='ID')
df_T2.to_csv('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA_T2.csv', index=True, index_label='ID')
df_T3.to_csv('/content/MyDrive/MyDrive/MUCSI/TFM/datos/TCA_T3.csv', index=True, index_label='ID')

# %%
df.to_excel('/content/MyDrive/MyDrive/MUCSI/TFM/TCA.xlsx', index=False)
